# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def grad_desc(x,y):
    m_curr=b_curr=0
    iterations=10000
    n=len(x)
    learn_rate=0.08

    for i in range (iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n) * sum(x*(y-y_predicted))
        bd= -(2/n) * sum(y-y_predicted)
        m_curr = m_curr - learn_rate * md
        b_curr = b_curr - learn_rate * bd
        print("m{},b{},cost{},iterations{}".format(m_curr,b_curr,cost,i))

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])

# %%
grad_desc(x,y)
# Out:
# m4.96,b1.44,cost89.0,iterations0
# m0.4991999999999983,b0.26879999999999993,cost71.10560000000002,iterations1
# m4.451584000000002,b1.426176000000001,cost56.8297702400001,iterations2
# m0.892231679999997,b0.5012275199999995,cost45.43965675929613,iterations3
# m4.041314713600002,b1.432759910400001,cost36.35088701894832,iterations4
# m1.2008760606719973,b0.7036872622079998,cost29.097483330142282,iterations5
# m3.7095643080294423,b1.4546767911321612,cost23.307872849944438,iterations6
# m1.4424862661541864,b0.881337636696883,cost18.685758762535738,iterations7
# m3.4406683721083144,b1.4879302070713722,cost14.994867596913156,iterations8
# m1.6308855378034224,b1.0383405553279617,cost12.046787238456794,iterations9
# m3.2221235247119777,b1.5293810083298451,cost9.691269350698109,iterations10
# m1.7770832372205707,b1.1780607551353204,cost7.8084968312098315,iterations11
# m3.0439475772474127,b1.5765710804477953,cost6.302918117062937,iterations12
# ...

# %% [markdown]
# EXERCISE

# %%
test_score=pd.read_csv("gradient_descent\\test_scores.csv")
test_score
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x=np.array(test_score['math'].values)
y=np.array(test_score['cs'].values)

# %%
import math
def gradient_descent(x,y):
    current_m = current_b = 0
    iterations = 1000000
    n=len(x)
    learning_rate = 0.0002
    prev_cost = 0
    
    for i in range(iterations):
        y_predicted = current_m * x + current_b
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        if math.isclose(prev_cost, cost, abs_tol=1e-20):
            print(current_m,current_b)
            break
        md = -(2/n) * sum(x*(y-y_predicted))
        bd = -(2/n) * sum(y-y_predicted)
        current_m = current_m - learning_rate * md
        current_b = current_b - learning_rate * bd
        prev_cost = cost

# %%
gradient_descent(x,y)
# Out:
# 1.0192813672901453 1.8057199989594932

# %%
from sklearn import linear_model
reg_verification = linear_model.LinearRegression()
reg_verification.fit(test_score[['math']].values,test_score[['cs']].values)
# Out:
# LinearRegression()

# %%
reg_verification.coef_
# Out:
# array([[1.01773624]])

# %%
reg_verification.intercept_
# Out:
# array([1.91521931])

# %% [markdown]
# We can see that our gradient descent is quite close to the linear regression algorithm.
